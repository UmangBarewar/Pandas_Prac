# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import pandas as pd

# %%
car_series=pd.Series(["BMW","Volvo","Audi"])
car_series
# Out:
# 0      BMW
# 1    Volvo
# 2     Audi
# dtype: object

# %%
color=pd.Series(["Red","Blue","Green"])
color
# Out:
# 0      Red
# 1     Blue
# 2    Green
# dtype: object

# %%
car_data=pd.DataFrame({"Car_make":car_series,"Color":color})
car_data
# Out:
#   Car_make  Color
# 0      BMW    Red
# 1    Volvo   Blue
# 2     Audi  Green

# %%
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
car_sales.to_csv("exp.csv",index=False)

# %%
exp_sales=pd.read_csv("exp.csv")
exp_sales
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %% [markdown]
# how to insert from url

# %%
heart_dis=pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-extended.csv")

# %%
heart_dis
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %% [markdown]
# ## Checking how to use markdown

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)        Doors         Price
# count    1000.000000  1000.000000   1000.000000
# mean   131073.708000     4.014000  16045.665000
# std     68859.723885     0.379405   8630.794219
# min     10148.000000     3.000000   2796.000000
# 25%     71238.000000     4.000000   9481.500000
# 50%    131202.000000     4.000000  14264.000000
# 75%    192372.750000     4.000000  20738.750000
# max    249860.000000     5.000000  52458.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           1000 non-null   object
#  1   Colour         1000 non-null   object
#  2   Odometer (KM)  1000 non-null   int64
#  3   Doors          1000 non-null   int64
#  4   Price          1000 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %% [markdown]
# # Viewing and Selecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0   Honda  White          35431      4  15323
# 1     BMW   Blue         192714      5  19943
# 2   Honda  White          84714      4  28343
# 3  Toyota  White         154365      4  13434
# 4  Nissan   Blue         181577      3  14043

# %%
car_sales.tail(7)
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 993  Nissan  Black         162523      4   4696
# 994     BMW   Blue         163322      3  31666
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732

# %%
#loc=index and iloc=position
animals =  pd.Series(["Tiger","Lion","Wolves","Panda","Deer"],index=[0,3,9,8,3])
animals
# Out:
# 0     Tiger
# 3      Lion
# 9    Wolves
# 8     Panda
# 3      Deer
# dtype: object

# %%
animals.loc[3]
# Out:
# 3    Lion
# 3    Deer
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'Panda'

# %%
car_sales.Make
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996    Nissan
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
car_sales["Make"]
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996    Nissan
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
pd.crosstab(car_sales["Make"],car_sales["Doors"])
# Out:
# Doors    3    4   5
# Make
# BMW     21    0  79
# Honda    0  304   0
# Nissan  44  154   0
# Toyota   0  398   0

# %%
# %matplotlib inline

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales["Price"].dtype
# Out:
# dtype('int64')

# %% [markdown]
# # Manipulating Data

# %%
miss=pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-missing-data.csv")
miss
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
miss["Odometer"].fillna(miss["Odometer"].mean(),inplace=True)
miss["Odometer"]
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
seats=pd.Series([5,5,5,5,5])
miss["Seats"]=seats

# %%
miss
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000    5.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    NaN
# 6   Honda    NaN   92302.666667    4.0   $7,500    NaN
# 7   Honda   Blue   92302.666667    4.0      NaN    NaN
# 8  Toyota  White   60000.000000    NaN      NaN    NaN
# 9     NaN  White   31600.000000    4.0   $9,700    NaN

# %%
miss["Seats"].fillna(5,inplace=True)

# %%
miss
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0
# 1   Honda    Red   87899.000000    4.0   $5,000    5.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0
# 6   Honda    NaN   92302.666667    4.0   $7,500    5.0
# 7   Honda   Blue   92302.666667    4.0      NaN    5.0
# 8  Toyota  White   60000.000000    NaN      NaN    5.0
# 9     NaN  White   31600.000000    4.0   $9,700    5.0

# %%
Fuel_eco=[14,7,9,6,22,12,23,19,20,10]
miss["Fuel_eco"]=Fuel_eco

# %%
miss
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel_eco
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0        14
# 1   Honda    Red   87899.000000    4.0   $5,000    5.0         7
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0         9
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0         6
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0        22
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0        12
# 6   Honda    NaN   92302.666667    4.0   $7,500    5.0        23
# 7   Honda   Blue   92302.666667    4.0      NaN    5.0        19
# 8  Toyota  White   60000.000000    NaN      NaN    5.0        20
# 9     NaN  White   31600.000000    4.0   $9,700    5.0        10

# %%
miss["random"]=miss["Odometer"]*5

# %%
miss
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel_eco        random
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0        14  7.502150e+05
# 1   Honda    Red   87899.000000    4.0   $5,000    5.0         7  4.394950e+05
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0         9  4.615133e+05
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0         6  5.589500e+04
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0        22  1.065475e+06
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0        12  4.615133e+05
# 6   Honda    NaN   92302.666667    4.0   $7,500    5.0        23  4.615133e+05
# 7   Honda   Blue   92302.666667    4.0      NaN    5.0        19  4.615133e+05
# 8  Toyota  White   60000.000000    NaN      NaN    5.0        20  3.000000e+05
# 9     NaN  White   31600.000000    4.0   $9,700    5.0        10  1.580000e+05

# %%
miss["Wheels"]=4
miss
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel_eco  \
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0        14
# 1   Honda    Red   87899.000000    4.0   $5,000    5.0         7
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0         9
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0         6
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0        22
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0        12
# 6   Honda    NaN   92302.666667    4.0   $7,500    5.0        23
# 7   Honda   Blue   92302.666667    4.0      NaN    5.0        19
# 8  Toyota  White   60000.000000    NaN      NaN    5.0        20
# 9     NaN  White   31600.000000    4.0   $9,700    5.0        10
#
#          random  Wheels
# 0  7.502150e+05       4
# 1  4.394950e+05       4
# 2  4.615133e+05       4
# 3  5.589500e+04       4
# 4  1.065475e+06       4
# 5  4.615133e+05       4
# 6  4.615133e+05       4
# 7  4.615133e+05       4
# ...

# %%
miss.sample(frac=0.5)
# Out:
#      Make Colour       Odometer  Doors   Price  Seats  Fuel_eco  \
# 1   Honda    Red   87899.000000    4.0  $5,000    5.0         7
# 9     NaN  White   31600.000000    4.0  $9,700    5.0        10
# 5  Toyota  Green   92302.666667    4.0  $4,500    5.0        12
# 6   Honda    NaN   92302.666667    4.0  $7,500    5.0        23
# 0  Toyota  White  150043.000000    4.0  $4,000    5.0        14
#
#           random  Wheels
# 1  439495.000000       4
# 9  158000.000000       4
# 5  461513.333333       4
# 6  461513.333333       4
# 0  750215.000000       4

# %%
miss["Odometer (miles)"]=miss["Odometer"].apply(lambda x:x/1.6)

# %%
miss
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Fuel_eco  \
# 0  Toyota  White  150043.000000    4.0   $4,000    5.0        14
# 1   Honda    Red   87899.000000    4.0   $5,000    5.0         7
# 2  Toyota   Blue   92302.666667    3.0   $7,000    5.0         9
# 3     BMW  Black   11179.000000    5.0  $22,000    5.0         6
# 4  Nissan  White  213095.000000    4.0   $3,500    5.0        22
# 5  Toyota  Green   92302.666667    4.0   $4,500    5.0        12
# 6   Honda    NaN   92302.666667    4.0   $7,500    5.0        23
# 7   Honda   Blue   92302.666667    4.0      NaN    5.0        19
# 8  Toyota  White   60000.000000    NaN      NaN    5.0        20
# 9     NaN  White   31600.000000    4.0   $9,700    5.0        10
#
#          random  Wheels  Odometer (miles)
# 0  7.502150e+05       4      93776.875000
# 1  4.394950e+05       4      54936.875000
# 2  4.615133e+05       4      57689.166667
# 3  5.589500e+04       4       6986.875000
# ...
